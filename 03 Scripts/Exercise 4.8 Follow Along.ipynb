# %% [raw]
# # Import libraries
# import pandas as pd
# import numpy as np
# import os

# %%
# data import path

path  = r'C:\Users\Layzr\Desktop\School\Data Immersion Part 4\Achievement 4'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
# creating dataframe of only the first 1 million rows

df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df.head(10)
# Out:
#    order_id  user_id eval_set  customer_order_count  orders_day_of_week  \
# 0   2539329        1    prior                     1                   2
# 1   2539329        1    prior                     1                   2
# 2   2539329        1    prior                     1                   2
# 3   2539329        1    prior                     1                   2
# 4   2539329        1    prior                     1                   2
# 5   2398795        1    prior                     2                   3
# 6   2398795        1    prior                     2                   3
# 7   2398795        1    prior                     2                   3
# 8   2398795        1    prior                     2                   3
# 9   2398795        1    prior                     2                   3
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# ...

# %%
df.groupby('product_name')

# %%
# using groupby to find the mean of the department_id column with a customers order count

df.groupby('department_id').agg({'customer_order_count': ['mean']})
# Out:
#               customer_order_count
#                               mean
# department_id
# 1                        14.800024
# 2                        17.091743
# 3                        17.913544
# 4                        17.893092
# 5                        15.214270
# 6                        15.382135
# 7                        17.694027
# 8                        16.458105
# 9                        15.957363
# 10                       20.091818
# 11                       16.482026
# 12                       15.615061
# 13                       16.484023
# 14                       17.524632
# 15                       15.691875
# 16                       18.014071
# 17                       16.150593
# 18                       19.602850
# 19                       17.631340
# 20                       17.138607
# 21                       21.956893

# %%
# different format of the same syntax used above

df.groupby('department_id')['customer_order_count'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: customer_order_count, dtype: float64

# %%
# adding min and max to the syntax

df.groupby('department_id').agg({'customer_order_count': ['mean', 'min', 'max']})
# Out:
#               customer_order_count
#                               mean min max
# department_id
# 1                        14.800024   1  99
# 2                        17.091743   1  98
# 3                        17.913544   1  99
# 4                        17.893092   1  99
# 5                        15.214270   1  99
# 6                        15.382135   1  99
# 7                        17.694027   1  99
# 8                        16.458105   1  91
# 9                        15.957363   1  99
# 10                       20.091818   1  99
# 11                       16.482026   1  99
# 12                       15.615061   1  99
# 13                       16.484023   1  99
# 14                       17.524632   1  99
# 15                       15.691875   1  99
# 16                       18.014071   1  99
# 17                       16.150593   1  99
# 18                       19.602850   1  99
# 19                       17.631340   1  99
# 20                       17.138607   1  99
# ...

# %%
# creating the max_order column to find customer loyalty

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['customer_order_count'].transform(np.max)
# Out:
# C:\Users\Layzr\AppData\Local\Temp\ipykernel_17048\2981464315.py:3: FutureWarning: The provided callable <function max at 0x0000021AE16E72E0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['customer_order_count'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  customer_order_count  orders_day_of_week  \
# 0    2539329        1    prior                     1                   2
# 1    2539329        1    prior                     1                   2
# 2    2539329        1    prior                     1                   2
# 3    2539329        1    prior                     1                   2
# 4    2539329        1    prior                     1                   2
# 5    2398795        1    prior                     2                   3
# 6    2398795        1    prior                     2                   3
# 7    2398795        1    prior                     2                   3
# 8    2398795        1    prior                     2                   3
# 9    2398795        1    prior                     2                   3
# 10   2398795        1    prior                     2                   3
# 11    473747        1    prior                     3                   3
# ...

# %%
# turning off any restriction of .head command

pd.options.display.max_rows = None

# %%
# defining a customers loyalty

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# checking the loyalty flag column

ords_prods_merge[['user_id', 'loyalty_flag', 'customer_order_count']].head(60)
# Out:
#     user_id      loyalty_flag  customer_order_count
# 0         1      New customer                     1
# 1         1      New customer                     1
# 2         1      New customer                     1
# 3         1      New customer                     1
# 4         1      New customer                     1
# 5         1      New customer                     2
# 6         1      New customer                     2
# 7         1      New customer                     2
# 8         1      New customer                     2
# 9         1      New customer                     2
# 10        1      New customer                     2
# 11        1      New customer                     3
# 12        1      New customer                     3
# 13        1      New customer                     3
# 14        1      New customer                     3
# 15        1      New customer                     3
# 16        1      New customer                     4
# ...

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge_added_columns.pkl'))
